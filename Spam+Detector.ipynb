# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
spam = pd.read_csv("Spam_Messages_Data.txt", sep = "\t", names=["label", "message"])

# %%
print(spam.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazy', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8018

# %%
word_features
# Out:
# dict_keys(['jurong', 'point', 'crazy', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', 'lar', 'joke', 'wif', 'oni', 'free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18', 'dun', 'say', 'early', 'hor', 'already', 'nah', "n't", 'think', 'usf', 'live', 'around', 'though', 'freemsg', 'hey', 'darling', 'week', 'word', 'back', 'like', 'fun', 'still', 'xxx', 'chgs', 'send', 'â£1.50', 'rcv', 'even', 'brother', 'speak', 'treat', 'aid', 'patent', 'per', 'request', "'melle", 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'callers', 'press', 'copy', 'friends', 'winner', 'value', 'network', 'customer', 'select', 'receivea', 'â£900', 'prize', 'reward', 'claim', 'call', '09061701461.', 'code', 'kl341', 'valid', 'hours', 'mobile', 'months', 'entitle', 'update', 'latest', 'colour', 'mobiles', 'camera', '08002986030', 'gon', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', "'ve", 'cry', 'enough', 'today', 'six', 'chance', 'cash', '100', '20,000', 'pound', 'csh11', '87575.', 'cost', '150p/day', '6days', '16+', 'tsandcs', 'reply', 'info', 'urgent', 'membership', 'â£100,000', 'jackpot', '81010', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18', 'search', 'right', 'thank', 'breather', 'promise', 'wont', 'take', 'help', 'grant', 'fulfil', 'wonderful', 'bless', 'time', 'date', 'sunday', 'xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'next', 'message', 'http', '//wap', 'xxxmobilemovieclub.com', 'n=qjkgighjjgcbl', 'watch', 'remember', 'spell', 'name', 'yes', 'naughty', 'make', 'wet', 'fine', 'thatâ', 'way', 'feel', 'gota', 'england', 'macedonia', 'dont', 'miss', 'goals/team', 'news', 'national', 'team', '87077', 'try', 'wales', 'scotland', '4txt/ãº1.20', 'poboxox36504w45wq', 'seriously', 'iâ€˜m', 'pay', 'first', 'stock', 'comin', 'aft', 'finish', 'lunch', 'str', 'lor', 'ard', 'smth', 'ffffffffff', 'alright', 'meet', 'sooner', 'force', 'eat', 'slice', 'really', 'hungry', 'tho', 'suck', 'mark', 'worry', 'know', 'sick', 'turn', 'pizza', 'lol', 'always', 'convince', 'catch', 'bus', 'fry', 'egg', 'tea', 'mom', 'leave', 'dinner', 'love', 'amp', "'re", 'pack', 'car', "'ll", 'let', 'room', 'ahhh', 'work', 'vaguely', 'wait', 'clear', 'sure', 'sarcastic', 'yeah', 'apologetic', 'fall', 'actin', 'spoil', 'child', 'till', 'badly', 'cheer', 'tell', 'anything', 'fear', 'faint', 'housework', 'quick', 'cuppa', 'subscription', 'ringtone', 'charge', 'â£5/month', 'please', 'confirm', 'yup', 'look', 'msg', 'xuhui', 'learn', '2nd', 'lesson', '8am', 'oops', 'roommate', 'see', 'letter', 'decide', 'hello', 'saturday', 'texting', 'tomo', 'invite', 'pls', 'ahead', 'watts', 'weekend', 'abiola', 'forget', 'need', 'crave', 'sweet', 'arabian', 'steed', 'mmmmmm', 'yummy', '07732584351', 'rodger', 'burn', 'sms', 'nokia', 'camcorder', '08000930705', 'delivery', 'tomorrow', 'hope', 'man', 'well', 'endow', 'inch', 'hep', 'immunisation', 'nigeria', 'fair', 'hopefully', 'tyler', 'could', 'maybe', 'ask', 'bite', 'stubborn', 'hospital', 'keep', 'weak', 'sucker', 'hospitals', 'suckers', 'saw', 'class', 'gram', 'usually', 'run', 'half', 'eighth', 'smarter', 'almost', 'whole', 'second', 'fyi', 'ride', 'morning', 'crash', 'place', 'wow', 'never', 'realize', 'embarassed', 'accomodations', 'since', 'best', 'seem', 'happy', 'cave', 'sorry', 'give', 'offer', 'embarassing', 'sptv', 'new', 'jersey', 'devil', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'mallika', 'sherawat', 'yesterday', 'find', 'url', 'congrats', 'year', 'special', 'cinema', 'pass', '09061209465', 'suprman', 'matrix3', 'starwars3', 'etc', 'bx420-ip4-5we', '150pm', 'later', 'reach', 'gauti', 'sehwag', 'odi', 'series', 'pick', 'burger', 'move', 'pain', 'kill', 'good', 'girls', 'situation', 'seekers', 'part', 'check', 'roommates', 'forever', 'come', 'double', 'hair', 'dresser ...

# %% [markdown]
# ### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(jurong)': False, 'contains(point)': False, 'contains(crazy)': False, 'contains(available)': False, 'contains(bugis)': False, 'contains(great)': False, 'contains(world)': False, 'contains(buffet)': False, 'contains(...)': False, 'contains(cine)': False, 'contains(get)': False, 'contains(amore)': False, 'contains(wat)': False, 'contains(lar)': False, 'contains(joke)': False, 'contains(wif)': False, 'contains(oni)': False, 'contains(free)': False, 'contains(entry)': False, 'contains(wkly)': False, 'contains(comp)': False, 'contains(win)': False, 'contains(cup)': False, 'contains(final)': False, 'contains(tkts)': False, 'contains(21st)': False, 'contains(may)': False, 'contains(2005.)': False, 'contains(text)': False, 'contains(87121)': False, 'contains(receive)': False, 'contains(question)': False, 'contains(std)': False, 'contains(txt)': False, 'contains(rate)': False, 'contains(apply)': False, 'contains(08452810075over18)': False, 'contains(dun)': False, 'contains(say)': False, 'contains(early)': False, 'contains(hor)': False, 'contains(already)': False, 'contains(nah)': False, "contains(n't)": False, 'contains(think)': False, 'contains(usf)': False, 'contains(live)': False, 'contains(around)': False, 'contains(though)': False, 'contains(freemsg)': False, 'contains(hey)': False, 'contains(darling)': False, 'contains(week)': False, 'contains(word)': False, 'contains(back)': False, 'contains(like)': False, 'contains(fun)': False, 'contains(still)': False, 'contains(xxx)': False, 'contains(chgs)': False, 'contains(send)': False, 'contains(â£1.50)': False, 'contains(rcv)': False, 'contains(even)': False, 'contains(brother)': False, 'contains(speak)': False, 'contains(treat)': False, 'contains(aid)': False, 'contains(patent)': False, 'contains(per)': False, 'contains(request)': False, "contains('melle)": False, 'contains(melle)': False, 'contains(oru)': False, 'contains(minnaminunginte)': False, 'contains(nurungu)': False, 'contains(vettam)': False, 'contains(set)': False, 'contains(callertune)': False, 'contains(callers)': False, 'contains(press)': False, 'contains(copy)': False, 'contains(friends)': False, 'contains(winner)': False, 'contains(value)': False, 'contains(network)': False, 'contains(customer)': False, 'contains(select)': False, 'contains(receivea)': False, 'contains(â£900)': False, 'contains(prize)': False, 'contains(reward)': False, 'contains(claim)': False, 'contains(call)': False, 'contains(09061701461.)': False, 'contains(code)': False, 'contains(kl341)': False, 'contains(valid)': False, 'contains(hours)': False, 'contains(mobile)': False, 'contains(months)': False, 'contains(entitle)': False, 'contains(update)': False, 'contains(latest)': False, 'contains(colour)': False, 'contains(mobiles)': False, 'contains(camera)': False, 'contains(08002986030)': False, 'contains(gon)': False, 'contains(home)': False, 'contains(soon)': False, 'contains(want)': False, 'contains(talk)': False, 'contains(stuff)': False, 'contains(anymore)': False, 'contains(tonight)': False, "contains('ve)": False, 'contains(cry)': False, 'contains(enough)': False, 'contains(today)': False, 'contains(six)': False, 'contains(chance)': False, 'contains(cash)': False, 'contains(100)': False, 'contains(20,000)': False, 'contains(pound)': False, 'contains(csh11)': False, 'contains(87575.)': False, 'contains(cost)': False, 'contains(150p/day)': False, 'contains(6days)': False, 'contains(16+)': False, 'contains(tsandcs)': False, 'contains(reply)': False, 'contains(info)': False, 'contains(urgent)': False, 'contains(membership)': False, 'contains(â£100,000)': False, 'contains(jackpot)': False, 'contains(81010)': False, 'contains(www.dbuk.net)': False, 'contains(lccltd)': False, 'contains(pobox)': False, 'contains(4403ldnw1a7rw18)': False, 'contains(search)': False, 'contains(right)': False, 'contains(thank)': False, 'contains(breather)': False, 'contains(promise)': False, 'contains(wont)': False, 'contains(take)': False, 'contains(help)': F ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9916984518734575

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.9775784753363229

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contains(award) = True             spam : ham    =    205.2 : 1.0
#        contains(service) = True             spam : ham    =    108.3 : 1.0
#           contains(code) = True             spam : ham    =     97.2 : 1.0
#         contains(urgent) = True             spam : ham    =     80.6 : 1.0
#         contains(latest) = True             spam : ham    =     76.5 : 1.0
#            contains(txt) = True             spam : ham    =     75.0 : 1.0
#        contains(private) = True             spam : ham    =     67.0 : 1.0
#         contains(reveal) = True             spam : ham    =     67.0 : 1.0
#         contains(camera) = True             spam : ham    =     66.1 : 1.0
#          contains(nokia) = True             spam : ham    =     65.7 : 1.0
#            contains(100) = True             spam : ham    =     62.7 : 1.0
#           contains(club) = True             spam : ham    =     62.7 : 1.0
#         contains(expire) = True             spam : ham    =     62.7 : 1.0
#          contains(video) = True             spam : ham    =     60.9 : 1.0
# contains(congratulations) = True             spam : ham    =     54.0 : 1.0
#          contains(final) = True             spam : ham    =     54.0 : 1.0
#        contains(attempt) = True             spam : ham    =     53.1 : 1.0
#       contains(landline) = True             spam : ham    =     53.1 : 1.0
#           contains(land) = True             spam : ham    =     49.7 : 1.0
#       contains(customer) = True             spam : ham    =     47.7 : 1.0
#            contains(box) = True             spam : ham    =     47.2 : 1.0
#          contains(music) = True             spam : ham    =     45.4 : 1.0
#            contains(opt) = True             spam : ham    =     45.4 : 1.0
#           contains(quiz) = True             spam : ham    =     45.4 : 1.0
#        contains(voucher) = True             spam : ham    =     45.4 : 1.0
#           contains(rate) = True             spam : ham    =     42.8 : 1.0
#         contains(mobile) = True             spam : ham    =     42.5 : 1.0
#            contains(del) = True             spam : ham    =     41.0 : 1.0
#         contains(txting) = True             spam : ham    =     41.0 : 1.0
#          contains(apply) = True             spam : ham    =     39.8 : 1.0
#         contains(orange) = True             spam : ham    =     39.8 : 1.0
#           contains(comp) = True             spam : ham    =     36.7 : 1.0
#       contains(discount) = True             spam : ham    =     36.7 : 1.0
#         contains(reward) = True             spam : ham    =     36.7 : 1.0
#        contains(receive) = True             spam : ham    =     36.7 : 1.0
#           contains(draw) = True             spam : ham    =     34.8 : 1.0
#        contains(contact) = True             spam : ham    =     33.1 : 1.0
#           contains(info) = True             spam : ham    =     32.4 : 1.0
#        contains(network) = True             spam : ham    =     31.0 : 1.0
#           contains(line) = True             spam : ham    =     30.4 : 1.0
#            contains(mat) = True             spam : ham    =     29.8 : 1.0
#            contains(sex) = True             spam : ham    =     29.8 : 1.0
#         contains(arrive) = True             spam : ham    =     28.1 : 1.0
#        contains(auction) = True             spam : ham    =     28.1 : 1.0
#           contains(sony) = True             spam : ham    =     28.1 : 1.0
#            contains(win) = True             spam : ham    =     27.2 : 1.0
#         contains(select) = True             spam : ham    =     25.3 : 1.0
#          contains(pound) = True             spam : ham    =     25.2 : 1.0
#           contains(cash) = True             spam : ham    =     25.0 : 1.0
#         contains(player) = True             spam : ham    =     24.6 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
